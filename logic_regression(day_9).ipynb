# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression as LOR
from sklearn.model_selection import train_test_split as TTS
from sklearn.metrics import accuracy_score, recall_score,precision_score,f1_score,confusion_matrix
import seaborn as sns

# %%
url="https://raw.github.com/ravardh/Database-sample-Files/main/diabetes.csv"
df=pd.read_csv(url)
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.672   32        1
# 3                       0.167   21        0
# 4                       2.288   33        1
# ..                        ...  ...      ...
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0
#
# [768 rows x 9 columns]

# %%
X=df.drop(columns=['Outcome'])
Y=df['Outcome']

# %%
X
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age
# 0                       0.627   50
# 1                       0.351   31
# 2                       0.672   32
# 3                       0.167   21
# 4                       2.288   33
# ..                        ...  ...
# 763                     0.171   63
# 764                     0.340   27
# 765                     0.245   30
# 766                     0.349   47
# 767                     0.315   23
#
# [768 rows x 8 columns]

# %%
Y
# Out:
# 0      1
# 1      0
# 2      1
# 3      0
# 4      1
#       ..
# 763    0
# 764    0
# 765    0
# 766    1
# 767    0
# Name: Outcome, Length: 768, dtype: int64

# %%
X_train,X_test,Y_train,Y_test = TTS(X,Y,test_size=0.30,random_state=0)

# %%
print(X_train,X_test,Y_train,X_test)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 580            0      151             90             46        0  42.1
# 418            1       83             68              0        0  18.2
# 764            2      122             70             27        0  36.8
# 363            4      146             78              0        0  38.5
# 757            0      123             72              0        0  36.3
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 192            7      159             66              0        0  30.4
# 629            4       94             65             22        0  24.7
# 559           11       85             74              0        0  30.1
# 684            5      136             82              0        0   0.0
#
#      DiabetesPedigreeFunction  Age
# 580                     0.371   21
# 418                     0.624   27
# 764                     0.340   27
# 363                     0.520   67
# 757                     0.258   52
# ..                        ...  ...
# 763                     0.171   63
# 192                     0.383   36
# 629                     0.148   21
# 559                     0.300   35
# 684                     0.640   69
#
# [537 rows x 8 columns]      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 661            1      199             76             43        0  42.9
# 122            2      107             74             30      100  33.6
# 113            4       76             62              0        0  34.0
# 14             5      166             72             19      175  25.8
# 529            0      111             65              0        0  24.6
# ..           ...      ...            ...            ...      ...   ...
# 165            6      104             74             18      156  29.9
# 188            8      109             76             39      114  27.9
# 334            1       95             60             18       58  23.9
# 758            1      106             76              0        0  37.5
# 34            10      122             78             31        0  27.6
#
#      DiabetesPedigreeFunction  Age
# 661                     1.394   22
# 122                     0.404   23
# 113                     0.391   25
# 14                      0.587   51
# 529                     0.660   31
# ..                        ...  ...
# 165                     0.722   41
# 188                     0.640   31
# 334                     0.260   22
# 758                     0.197   26
# 34                      0.512   45
#
# [231 rows x 8 columns] 580    1
# 418    0
# 764    0
# 363    1
# 757    1
#       ..
# 763    0
# 192    1
# 629    0
# 559    0
# 684    0
# Name: Outcome, Length: 537, dtype: int64      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 661            1      199             76             43        0  42.9
# 122            2      107             74             30      100  33.6
# 113            4       76             62              0        0  34.0
# 14             5      166             72             19      175  25.8
# 529            0      111             65              0        0  24.6
# ..           ...      ...            ...            ...      ...   ...
# 165            6      104             74             18      156  29.9
# 188            8      109             76             39      114  27.9
# 334            1       95             60             18       58  23.9
# 758            1      106             76              0        0  37.5
# 34            10      122             78             31        0  27.6
#
#      DiabetesPedigreeFunction  Age
# 661                     1.394   22
# 122                     0.404   23
# 113                     0.391   25
# 14                      0.587   51
# 529                     0.660   31
# ..                        ...  ...
# 165                     0.722   41
# 188                     0.640   31
# 334                     0.260   22
# 758                     0.197   26
# 34                      0.512   45
#
# [231 rows x 8 columns]

# %%
model = LOR(max_iter=1000)
model.fit(X_train,Y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %%
Y_pred = model.predict(X_test)

# %%
X_test
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 661            1      199             76             43        0  42.9
# 122            2      107             74             30      100  33.6
# 113            4       76             62              0        0  34.0
# 14             5      166             72             19      175  25.8
# 529            0      111             65              0        0  24.6
# ..           ...      ...            ...            ...      ...   ...
# 165            6      104             74             18      156  29.9
# 188            8      109             76             39      114  27.9
# 334            1       95             60             18       58  23.9
# 758            1      106             76              0        0  37.5
# 34            10      122             78             31        0  27.6
#
#      DiabetesPedigreeFunction  Age
# 661                     1.394   22
# 122                     0.404   23
# 113                     0.391   25
# 14                      0.587   51
# 529                     0.660   31
# ..                        ...  ...
# 165                     0.722   41
# 188                     0.640   31
# 334                     0.260   22
# 758                     0.197   26
# 34                      0.512   45
#
# [231 rows x 8 columns]

# %%
DF_test_predict = X_test
DF_test_predict["Y_test"]= Y_test
DF_test_predict["Y_pred"] = Y_pred
DF_test_predict
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 661            1      199             76             43        0  42.9
# 122            2      107             74             30      100  33.6
# 113            4       76             62              0        0  34.0
# 14             5      166             72             19      175  25.8
# 529            0      111             65              0        0  24.6
# ..           ...      ...            ...            ...      ...   ...
# 165            6      104             74             18      156  29.9
# 188            8      109             76             39      114  27.9
# 334            1       95             60             18       58  23.9
# 758            1      106             76              0        0  37.5
# 34            10      122             78             31        0  27.6
#
#      DiabetesPedigreeFunction  Age  Y_test  Y_pred
# 661                     1.394   22       1       1
# 122                     0.404   23       0       0
# 113                     0.391   25       0       0
# 14                      0.587   51       1       1
# 529                     0.660   31       0       0
# ..                        ...  ...     ...     ...
# 165                     0.722   41       1       0
# 188                     0.640   31       1       0
# 334                     0.260   22       0       0
# 758                     0.197   26       0       0
# 34                      0.512   45       0       0
#
# [231 rows x 10 columns]

# %%
CM=confusion_matrix(Y_test,Y_pred)
AS=accuracy_score(Y_test,Y_pred)
RS=recall_score(Y_test,Y_pred)
PS=precision_score(Y_test,Y_pred)
F1=f1_score(Y_test,Y_pred)
print(f"Accuracy score = {AS}\nRS=recall_score={RS}\nPS=precision_score={PS}\nF1=f1_score={F1}")
# Out:
# Accuracy score = 0.7792207792207793
# RS=recall_score=0.527027027027027
# PS=precision_score=0.7090909090909091
# F1=f1_score=0.6046511627906976

# %%
plt.figure(figsize=(15,5))
sns.heatmap(CM, annot=True,fmt='d',cmap='Reds',
           xticklabels=["Non-daibetic","Daibetic"],
           yticklabels=["Non-daibetic","Daibetic"]
           )
plt.xlabel('Predected')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()
